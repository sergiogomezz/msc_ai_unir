# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('wine.data', header=None, usecols=[1,2,3,4])

# %%
import pandas as pd
iris=pd.read_csv("https://raw.githubusercontent.com/toneloy/data/master/iris.csv", usecols=[0, 1, 2, 3])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot.hist(bins=8,edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd

df = pd.DataFrame()
histogram=iris.plot.hist(bins=8,edgecolor='black')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(data=iris, x='sepal_length', color='red')
plt.show()
ay= sns.boxplot(data=iris, x='sepal_width', color='blue')
plt.show()

# %%
cov_mat = iris.cov()

# %%
cov_mat
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
import seaborn as sns

# %%
ax = sns.heatmap(cov_mat, annot=True)

# %% [markdown]
# **Ejercicio 1**
# Necesitamos un conjunto de datos generado con un 10 % de outliers. Por
# tanto, generar el conjunto de datos con el siguiente código:

# %%
# define the x co-ordinates
import numpy as np
mu=0;
sigma=0.1;
X = np.random.normal(mu, sigma, (395, 1))

# %%
# define the y co-ordinates
Y = np.random.normal(mu * 2, sigma * 3, (395, 1))

# %% [markdown]
# *   Generar el diagrama de dispersión y comentar los resultados.
# *   Inmuebles y su descripción.
# *   Crear la matriz de correlación aplicando Pearson y comentar los resultados.
# *   Con el conjunto de datos de los inmuebles, generar la matriz de covarianza y comparar los datos obtenidos con la matriz de correlaciones construida en el punto anterior.
#
# *   Utilizar la Biblioteca de MatPlotLib para crear un diagrama de dispersión básico.
# *   Generar datos aleatoriaos mediante la función np.random.rand() .

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generar datos aleatorios
np.random.seed(42)
x = np.random.rand(50)
y = np.random.rand(50)

# %%
# Crear el diagrama de dispersión
plt.scatter(x, y)
# Configurar el título y las etiquetas de los ejes
plt.title("Diagrama de dispersión")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Mostrar el diagrama de dispersión
plt.show()
