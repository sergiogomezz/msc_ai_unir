# %%
import pandas as pd

df = pd.read_csv("data/out.csv")

# %%
df_2 = df[df['label']>0]

# %%
df_2.head()
# Out:
#       A   B  C  D  E                                         comentario  \
# 5000  0   2  2  0  6  barça,nunca,acaezar,segundo,tercero,estar,arbi...
# 5001  1  13  4  0  6  cristinar,cifuent,podrio,haber,ser,presidenta,...
# 5002  1   7  2  0  0  parecer,exagerado,pedir,mas,tres,año,prision,c...
# 5003  0   0  2  0  0  parecer,delincuente,negar,evidencia,prueba,ult...
# 5004  0   2  1  0  5  preguntarselo,fracasado,medio,carrera,mes,mast...
#
#       label       A_t       B_t       C_t  ...   Valor_1   Valor_2   Valor_3  \
# 5000    1.0 -0.287998 -0.289909  0.088042  ...  0.083493 -0.025356  0.119973
# 5001    1.0  0.781552  0.251141  0.592169  ...  0.196280  0.462811 -0.325577
# 5002    1.0  0.781552 -0.043977  0.088042  ... -0.034371  0.068809 -0.325577
# 5003    1.0 -0.287998 -0.388282  0.088042  ...  0.111824 -0.025356  0.119973
# 5004    1.0 -0.287998 -0.289909 -0.164022  ...  0.083493  0.047238  0.119973
#
# ...
